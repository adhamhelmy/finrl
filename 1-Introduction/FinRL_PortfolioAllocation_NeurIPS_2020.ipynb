# %% [markdown]
# <a href="https://colab.research.google.com/github/adhamhelmy/finrl/blob/main/1-Introduction/FinRL_PortfolioAllocation_NeurIPS_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations: https://towardsdatascience.com/finrl-for-quantitative-finance-tutorial-for-portfolio-allocation-9b417660c7cd
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for portfolio alloacation. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A represents the weight of a stock in the porfolio: a ∈ (-1,1). Assume our stock pool includes N stocks, we can use a list [a<sub>1</sub>, a<sub>2</sub>, ... , a<sub>N</sub>] to determine the weight for each stock in the porfotlio, where a<sub>i</sub> ∈ (-1,1), a<sub>1</sub>+ a<sub>2</sub>+...+a<sub>N</sub>=1. For example, "The weight of AAPL in the portfolio is 10%." is [0.1 , ...].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
# import condacolab
# condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-8nyep8e_
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-8nyep8e_
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit dcf6bde8d64e1a747673d24dde30dce195bc3cf1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-7brfh4hj/elegantrl_d0d3c1b4dac545a48e8615d708e861e0
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-7brfh4hj/elegantrl_d0d3c1b4dac545a48e8615d708e861e0
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 7c64395ff4c2b53892fe6f9eaa3b58947136ffc1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (3.1.60)
# Requirement already satisfied: jqdatasdk<2,>=1 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pandas-market-calendars<6,>=5 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (5.1.3)
# Requirement already satisfied: pyfolio-reloaded<0.10,>=0.9 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (0.9.9)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.51.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (1.6.1)
# Requirement already satisfied: selenium<5,>=4 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (4.32.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.7.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (3.4.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.12/dist-packages (from finrl==0.3.8) (0.2.58)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.11.10)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.4)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /usr/local/lib/python3.12/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.0.2)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.9.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.13.2)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.12/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (75.2.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.12/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (2025.10.5)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (43.0.3)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (3.5.0)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.12/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (1.22.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.17.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.12/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (2.0.44)
# Requirement already satisfied: pymysql>=0.7.6 in /usr/local/lib/python3.12/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.1.2)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (0.5.3)
# Requirement already satisfied: exchange-calendars>=3.3 in /usr/local/lib/python3.12/dist-packages (from pandas-market-calendars<6,>=5->finrl==0.3.8) (4.11.3)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.10.0)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2025.2)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.16.3)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.13.2)
# Requirement already satisfied: empyrical-reloaded>=0.5.9 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.5.12)
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.12/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (1.6.7)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in /usr/local/lib/python3.12/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (5.24.1)
# Requirement already satisfied: click!=8.3.0,>=7.0 in /usr/local/lib/python3.12/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (8.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.20.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (4.25.1)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (5.29.5)
# Requirement already satisfied: aiohttp_cors in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: colorful in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.5.8)
# Requirement already satisfied: py-spy>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.76.0)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-prometheus in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.58b0)
# Requirement already satisfied: opentelemetry-proto in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.37.0)
# Requirement already satisfied: prometheus_client>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.23.1)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (7.5.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (20.35.4)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.6.4)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (18.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2025.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2,>=1->finrl==0.3.8) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2,>=1->finrl==0.3.8) (3.6.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.12/dist-packages (from selenium<5,>=4->finrl==0.3.8) (0.32.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.12/dist-packages (from selenium<5,>=4->finrl==0.3.8) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.12/dist-packages (from selenium<5,>=4->finrl==0.3.8) (4.15.0)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.2.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.8.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.12.0.88)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.19.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.11.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.3.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from webdriver-manager<5,>=4->finrl==0.3.8) (1.2.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /usr/local/lib/python3.12/dist-packages (from wrds<4,>=3->finrl==0.3.8) (2.9.11)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.5.0)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.13.0)
# Requirement already satisfied: th in /usr/local/lib/python3.12/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: pycares>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.8) (4.11.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.8)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.0.0)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (1.0.5)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.2.9)
# Requirement already satisfied: bottleneck>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: pyluach>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (2.3.0)
# Requirement already satisfied: toolz>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (1.1.0)
# Requirement already satisfied: tzdata>=2025.2 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (2025.2)
# Requirement already satisfied: korean_lunar_calendar>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (0.3.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.9.0.post0)
# Requirement already satisfied: opentelemetry-api==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (0.58b0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api==1.37.0->opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (8.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.11)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.8) (3.2.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.3)
# Requirement already satisfied: ply<4.0,>=3.4 in /usr/local/lib/python3.12/dist-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.4.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.12/dist-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.12/dist-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8) (1.7.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.28.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.28.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.8) (2.0.1)
# Requirement already satisfied: niltype<2.0,>=0.3 in /usr/local/lib/python3.12/dist-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.23)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.72.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.38.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.8.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.3)
# Requirement already satisfied: h11<1,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (0.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api==1.37.0->opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (3.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import sys
sys.path.append("../FinRL-Library")

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
# dp = YahooFinanceProcessor()
# df = dp.download_data(start_date = '2008-01-01',
#                      end_date = '2021-10-31',
#                      ticker_list = config_tickers.DOW_30_TICKER, time_interval='1D')
df = YahooDownloader(start_date = '2008-01-01',
                     end_date = '2021-10-31',
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['WBA']: HTTPError('HTTP Error 404: ')
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Shape of DataFrame:  (98132, 8)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df.head()
# Out:
# Price        date      close       high        low       open      volume  \
# 0      2008-01-02   5.843454   6.006006   5.774776   5.976315  1079178800
# 1      2008-01-02  31.964485  32.266297  31.731268  31.964485     7934400
# 2      2008-01-02  38.702675  39.673274  38.513105  39.498870     8053700
# 3      2008-01-02  63.481606  64.375708  63.027221  64.177834     4303000
# 4      2008-01-02  44.217842  45.494983  43.854737  45.426117     6337800
#
# Price   tic  day
# 0      AAPL    2
# 1      AMGN    2
# 2       AXP    2
# 3        BA    2
# 4       CAT    2
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df.shape
# Out:
# (98132, 8)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

df = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df.shape
# Out:
# (94041, 16)

# %%
df.head()
# Out:
#              date      close       high        low       open      volume  \
# 0      2008-01-02   5.843454   6.006006   5.774776   5.976315  1079178800
# 3483   2008-01-02  31.964485  32.266297  31.731268  31.964485     7934400
# 6966   2008-01-02  38.702675  39.673274  38.513105  39.498870     8053700
# 10449  2008-01-02  63.481606  64.375708  63.027221  64.177834     4303000
# 13932  2008-01-02  44.217842  45.494983  43.854737  45.426117     6337800
#
#         tic  day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  \
# 0      AAPL    2   0.0  5.848623  5.840986   100.0 -66.666667  100.0
# 3483   AMGN    2   0.0  5.848623  5.840986   100.0 -66.666667  100.0
# 6966    AXP    2   0.0  5.848623  5.840986   100.0 -66.666667  100.0
# 10449    BA    2   0.0  5.848623  5.840986   100.0 -66.666667  100.0
# 13932   CAT    2   0.0  5.848623  5.840986   100.0 -66.666667  100.0
#
#        close_30_sma  close_60_sma
# 0          5.843454      5.843454
# 3483      31.964485     31.964485
# 6966      38.702675     38.702675
# 10449     63.481606     63.481606
# 13932     44.217842     44.217842
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Add covariance matrix as states

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values
  cov_list.append(covs)


df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df.shape
# Out:
# (87237, 18)

# %%
df.head()
# Out:
#          date      close       high        low       open     volume   tic  \
# 0  2008-12-31   2.559735   2.631414   2.559436   2.578330  607541200  AAPL
# 1  2008-12-31  39.612652  39.935041  39.139359  39.173655    6287200  AMGN
# 2  2008-12-31  14.254668  14.408358  13.762863  13.808970    9625600   AXP
# 3  2008-12-31  32.005882  32.290913  31.128291  31.195798    5443100    BA
# 4  2008-12-31  28.707743  28.984088  28.084362  28.084362    6277400   CAT
#
#    day      macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0    2 -0.081830   3.064709   2.431330  42.254781  -80.847156  16.129827
# 1    2  0.148413  40.433988  38.678810  51.060626   51.895905  10.431911
# 2    2 -0.914660  18.229859  12.377338  42.554843  -74.811831  25.744903
# 3    2 -0.279802  32.174385  28.867831  47.440231  157.921643   5.391946
# 4    2  0.635663  29.424678  24.681105  51.205305   98.904532  26.480643
#
#    close_30_sma  close_60_sma  \
# 0      2.723837      2.834898
# 1     38.872752     38.442671
# 2     15.391970     17.222407
# 3     30.327213     32.389915
# 4     25.877462     25.619594
#
#                                             cov_list  \
# 0  [[0.001348969167393465, 0.0004284132113294488,...
# 1  [[0.001348969167393465, 0.0004284132113294488,...
# 2  [[0.001348969167393465, 0.0004284132113294488,...
# 3  [[0.001348969167393465, 0.0004284132113294488,...
# 4  [[0.001348969167393465, 0.0004284132113294488,...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, '2009-01-01','2020-07-01')
#trade = data_split(df, '2020-01-01', config.END_DATE)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
train.head()
# Out:
#          date      close       high        low       open     volume   tic  \
# 0  2009-01-02   2.721687   2.730385   2.554038   2.575631  746015200  AAPL
# 0  2009-01-02  40.463203  40.524938  39.612645  40.188829    6547900  AMGN
# 0  2009-01-02  14.854065  15.000070  14.139410  14.270046   10955700   AXP
# 0  2009-01-02  33.941093  34.173619  32.088396  32.103398    7010200    BA
# 0  2009-01-02  30.147306  30.192293  28.733448  28.861981    7117200   CAT
#
#    day      macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0    4 -0.069496   3.051314   2.429280  45.440198  -30.508792   2.140145
# 0    4  0.219806  40.571832  38.645226  52.756852   94.549682   0.814235
# 0    4 -0.813441  18.050353  12.361661  43.957570  -42.018420  16.306885
# 0    4 -0.002010  32.948627  28.452126  50.822031  275.695957  20.529990
# 0    4  0.807831  29.911498  24.660857  53.661248  131.675820  34.780821
#
#    close_30_sma  close_60_sma  \
# 0      2.724676      2.835693
# 0     38.933342     38.526126
# 0     15.390689     17.108165
# 0     30.469478     32.344130
# 0     26.107106     25.620158
#
#                                             cov_list  \
# 0  [[0.0013661508417011094, 0.0004339387318031043...
# 0  [[0.0013661508417011094, 0.0004339387318031043...
# 0  [[0.0013661508417011094, 0.0004339387318031043...
# 0  [[0.0013661508417011094, 0.0004339387318031043...
# 0  [[0.0013661508417011094, 0.0004339387318031043...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step


    """
    metadata = {'render.modes': ['human']}

    def __init__(self,
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,))
        # Shape = (34, 30)
        # covariance matrix + technical indicators
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+len(self.tech_indicator_list),self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.terminal = False
        self.turbulence_threshold = turbulence_threshold
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]


    def step(self, actions):
        # print(self.day)
        self.terminal = self.day >= len(self.df.index.unique())-1
        # print(actions)

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(),'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()

            plt.plot(self.portfolio_return_memory,'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() !=0:
              sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                       df_daily_return['daily_return'].std()
              print("Sharpe: ",sharpe)
            print("=================================")

            return self.state, self.reward, self.terminal,{}

        else:
            #print("Model actions: ",actions)
            # actions are the portfolio weight
            # normalize to sum of 1
            #if (np.array(actions) - np.array(actions).min()).sum() != 0:
            #  norm_actions = (np.array(actions) - np.array(actions).min()) / (np.array(actions) - np.array(actions).min()).sum()
            #else:
            #  norm_actions = actions
            weights = self.softmax_normalization(actions)
            #print("Normalized actions: ", weights)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day,:]
            self.covs = self.data['cov_list'].values[0]
            self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
            #print(self.state)
            # calcualte portfolio return
            # individual stocks' return * weight
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values)-1)*weights)
            # update portfolio value
            new_portfolio_value = self.portfolio_value*(1+portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value
            #print("Step reward: ", self.reward)
            #self.reward = self.reward*self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]
        return self.state

    def render(self, mode='human'):
        return self.state

    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output


    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']

        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 27, State Space: 27

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4

}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)

# %%
# !pip install 'shimmy>=2.0'

env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# Collecting shimmy>=2.0
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from shimmy>=2.0) (2.0.2)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.12/dist-packages (from shimmy>=2.0) (1.2.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
# initialize
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
trained_a2c = agent.train_model(model=model_a2c,
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 196       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.87e+08  |
# |    reward             | 1671631.4 |
# |    reward_max         | 1671631.4 |
# |    reward_mean        | 1670252.0 |
# |    reward_min         | 1668512.4 |
# |    std                | 0.997     |
# |    value_loss         | 2.95e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 239       |
# |    iterations         | 200       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 2.52e+08  |
# |    reward             | 2141908.8 |
# |    reward_max         | 2163322.5 |
# |    reward_mean        | 2149994.5 |
# |    reward_min         | 2141908.8 |
# |    std                | 0.997     |
# |    value_loss         | 4.88e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 300       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 3.57e+08  |
# |    reward             | 3120895.8 |
# |    reward_max         | 3151816.2 |
# |    reward_mean        | 3106434.2 |
# |    reward_min         | 3065958.8 |
# |    std                | 0.997     |
# |    value_loss         | 1.08e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 400       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 4.36e+08  |
# |    reward             | 3804021.2 |
# |    reward_max         | 3804021.2 |
# |    reward_mean        | 3763410.8 |
# |    reward_min         | 3695373.8 |
# |    std                | 0.997     |
# |    value_loss         | 1.45e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 500       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 6.01e+08  |
# |    reward             | 5123272.5 |
# |    reward_max         | 5401135.0 |
# |    reward_mean        | 5280494.0 |
# |    reward_min         | 5123272.5 |
# |    std                | 0.996     |
# |    value_loss         | 2.93e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6315167.270143513
# Sharpe:  0.9712913171682948
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 600       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 599       |
# |    policy_loss        | 1.17e+08  |
# |    reward             | 1084547.0 |
# |    reward_max         | 1084600.1 |
# |    reward_mean        | 1080369.8 |
# |    reward_min         | 1072686.1 |
# |    std                | 0.995     |
# |    value_loss         | 1.17e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 700       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 699       |
# |    policy_loss        | 1.99e+08  |
# |    reward             | 1734829.9 |
# |    reward_max         | 1773461.4 |
# |    reward_mean        | 1750733.0 |
# |    reward_min         | 1734829.9 |
# |    std                | 0.995     |
# |    value_loss         | 3.28e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 269       |
# |    iterations         | 800       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 799       |
# |    policy_loss        | 3e+08     |
# |    reward             | 2428777.5 |
# |    reward_max         | 2445428.0 |
# |    reward_mean        | 2432837.5 |
# |    reward_min         | 2427923.0 |
# |    std                | 0.994     |
# |    value_loss         | 6.35e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 900       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.91e+08  |
# |    reward             | 3414223.5 |
# |    reward_max         | 3425166.2 |
# |    reward_mean        | 3419722.0 |
# |    reward_min         | 3414223.5 |
# |    std                | 0.994     |
# |    value_loss         | 1.23e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 1000      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 999       |
# |    policy_loss        | 4.77e+08  |
# |    reward             | 4121718.8 |
# |    reward_max         | 4192280.0 |
# |    reward_mean        | 4167946.2 |
# |    reward_min         | 4121718.8 |
# |    std                | 0.994     |
# |    value_loss         | 1.86e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 1100      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 6.76e+08  |
# |    reward             | 5830038.0 |
# |    reward_max         | 5915007.0 |
# |    reward_mean        | 5862673.0 |
# |    reward_min         | 5776808.0 |
# |    std                | 0.993     |
# |    value_loss         | 3.83e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6216033.382266632
# Sharpe:  0.9713509765733039
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 1200      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 1.5e+08   |
# |    reward             | 1285584.1 |
# |    reward_max         | 1285584.1 |
# |    reward_mean        | 1263852.6 |
# |    reward_min         | 1246898.8 |
# |    std                | 0.993     |
# |    value_loss         | 1.69e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 1300      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1299      |
# |    policy_loss        | 1.82e+08  |
# |    reward             | 1633366.6 |
# |    reward_max         | 1715330.5 |
# |    reward_mean        | 1680722.2 |
# |    reward_min         | 1633366.6 |
# |    std                | 0.992     |
# |    value_loss         | 2.9e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 1400      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1399      |
# |    policy_loss        | 2.77e+08  |
# |    reward             | 2538472.5 |
# |    reward_max         | 2538472.5 |
# |    reward_mean        | 2522670.2 |
# |    reward_min         | 2503011.8 |
# |    std                | 0.992     |
# |    value_loss         | 6.7e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 1500      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 3.43e+08  |
# |    reward             | 3169960.5 |
# |    reward_max         | 3169960.5 |
# |    reward_mean        | 3112025.8 |
# |    reward_min         | 3074771.5 |
# |    std                | 0.992     |
# |    value_loss         | 1.01e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 1600      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1599      |
# |    policy_loss        | 4.75e+08  |
# |    reward             | 4154435.8 |
# |    reward_max         | 4154435.8 |
# |    reward_mean        | 4116456.8 |
# |    reward_min         | 4087988.0 |
# |    std                | 0.992     |
# |    value_loss         | 1.78e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 267       |
# |    iterations         | 1700      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 6.5e+08   |
# |    reward             | 5606793.0 |
# |    reward_max         | 5606793.0 |
# |    reward_mean        | 5545206.0 |
# |    reward_min         | 5480335.5 |
# |    std                | 0.993     |
# |    value_loss         | 3.2e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5581199.839031728
# Sharpe:  0.9091898921812036
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 267       |
# |    iterations         | 1800      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 1.66e+08  |
# |    reward             | 1523019.6 |
# |    reward_max         | 1523019.6 |
# |    reward_mean        | 1505045.9 |
# |    reward_min         | 1489974.8 |
# |    std                | 0.991     |
# |    value_loss         | 2.35e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 1900      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 2.41e+08  |
# |    reward             | 2094384.9 |
# |    reward_max         | 2112849.8 |
# |    reward_mean        | 2101629.5 |
# |    reward_min         | 2090401.5 |
# |    std                | 0.991     |
# |    value_loss         | 4.69e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 2000      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1999      |
# |    policy_loss        | 3e+08     |
# |    reward             | 2890650.0 |
# |    reward_max         | 2900709.8 |
# |    reward_mean        | 2883371.0 |
# |    reward_min         | 2849822.5 |
# |    std                | 0.99      |
# |    value_loss         | 8.63e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 2100      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 3.54e+08  |
# |    reward             | 3365086.2 |
# |    reward_max         | 3365086.2 |
# |    reward_mean        | 3336394.8 |
# |    reward_min         | 3321448.8 |
# |    std                | 0.99      |
# |    value_loss         | 1.19e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 2200      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2199      |
# |    policy_loss        | 5.3e+08   |
# |    reward             | 4616552.5 |
# |    reward_max         | 4843972.0 |
# |    reward_mean        | 4765617.0 |
# |    reward_min         | 4616552.5 |
# |    std                | 0.99      |
# |    value_loss         | 2.56e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 267       |
# |    iterations         | 2300      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2299      |
# |    policy_loss        | 5.65e+08  |
# |    reward             | 4696573.5 |
# |    reward_max         | 5359544.0 |
# |    reward_mean        | 4876157.5 |
# |    reward_min         | 4667386.0 |
# |    std                | 0.989     |
# |    value_loss         | 3.09e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6007282.3555403575
# Sharpe:  0.9449474842300372
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 267       |
# |    iterations         | 2400      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2399      |
# |    policy_loss        | 1.68e+08  |
# |    reward             | 1511015.9 |
# |    reward_max         | 1511015.9 |
# |    reward_mean        | 1497207.6 |
# |    reward_min         | 1478966.4 |
# |    std                | 0.989     |
# |    value_loss         | 2.3e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 269       |
# |    iterations         | 2500      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2499      |
# |    policy_loss        | 2.08e+08  |
# |    reward             | 2051146.2 |
# |    reward_max         | 2051291.1 |
# |    reward_mean        | 2027698.9 |
# |    reward_min         | 2011372.9 |
# |    std                | 0.989     |
# |    value_loss         | 4.31e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 267       |
# |    iterations         | 2600      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2599      |
# |    policy_loss        | 3.28e+08  |
# |    reward             | 3002765.5 |
# |    reward_max         | 3002765.5 |
# |    reward_mean        | 2987115.0 |
# |    reward_min         | 2979232.0 |
# |    std                | 0.988     |
# |    value_loss         | 9.47e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 267       |
# |    iterations         | 2700      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 3.68e+08  |
# |    reward             | 3461987.5 |
# |    reward_max         | 3467332.5 |
# |    reward_mean        | 3459996.2 |
# |    reward_min         | 3449606.8 |
# |    std                | 0.988     |
# |    value_loss         | 1.28e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 268       |
# |    iterations         | 2800      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2799      |
# |    policy_loss        | 5.92e+08  |
# |    reward             | 5254397.5 |
# |    reward_max         | 5254397.5 |
# |    reward_mean        | 5236302.0 |
# |    reward_min         | 5223424.5 |
# |    std                | 0.988     |
# |    value_loss         | 2.84e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6018228.196514153
# Sharpe:  0.9426239685340012
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 269       |
# |    iterations         | 2900      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 1.06e+08  |
# |    reward             | 861101.4  |
# |    reward_max         | 875863.4  |
# |    reward_mean        | 857190.8  |
# |    reward_min         | 826051.2  |
# |    std                | 0.987     |
# |    value_loss         | 8.72e+12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 3000      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2999      |
# |    policy_loss        | 2.08e+08  |
# |    reward             | 1765393.1 |
# |    reward_max         | 1765393.1 |
# |    reward_mean        | 1761146.2 |
# |    reward_min         | 1757823.2 |
# |    std                | 0.987     |
# |    value_loss         | 3.29e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 3100      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3099      |
# |    policy_loss        | 2.34e+08  |
# |    reward             | 2189811.2 |
# |    reward_max         | 2193073.8 |
# |    reward_mean        | 2189902.5 |
# |    reward_min         | 2182395.5 |
# |    std                | 0.987     |
# |    value_loss         | 5.05e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 3200      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3199      |
# |    policy_loss        | 3.11e+08  |
# |    reward             | 3003292.0 |
# |    reward_max         | 3030505.5 |
# |    reward_mean        | 3012796.8 |
# |    reward_min         | 3003292.0 |
# |    std                | 0.987     |
# |    value_loss         | 9.35e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 3300      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 3.83e+08  |
# |    reward             | 3627180.2 |
# |    reward_max         | 3644150.2 |
# |    reward_mean        | 3629268.2 |
# |    reward_min         | 3617095.5 |
# |    std                | 0.987     |
# |    value_loss         | 1.4e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 3400      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3399      |
# |    policy_loss        | 4.98e+08  |
# |    reward             | 4979299.5 |
# |    reward_max         | 4979299.5 |
# |    reward_mean        | 4929615.5 |
# |    reward_min         | 4898063.0 |
# |    std                | 0.986     |
# |    value_loss         | 2.56e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5914215.25118153
# Sharpe:  0.9360570483953785
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 3500      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3499      |
# |    policy_loss        | 1.27e+08  |
# |    reward             | 1199049.1 |
# |    reward_max         | 1199049.1 |
# |    reward_mean        | 1190904.9 |
# |    reward_min         | 1167284.1 |
# |    std                | 0.985     |
# |    value_loss         | 1.41e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 3600      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3599      |
# |    policy_loss        | 1.99e+08  |
# |    reward             | 1794041.8 |
# |    reward_max         | 1794041.8 |
# |    reward_mean        | 1770980.8 |
# |    reward_min         | 1749756.2 |
# |    std                | 0.985     |
# |    value_loss         | 3.32e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 3700      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3699      |
# |    policy_loss        | 2.69e+08  |
# |    reward             | 2550514.5 |
# |    reward_max         | 2550514.5 |
# |    reward_mean        | 2536991.0 |
# |    reward_min         | 2529636.2 |
# |    std                | 0.984     |
# |    value_loss         | 6.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 3800      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3799      |
# |    policy_loss        | 3.8e+08   |
# |    reward             | 3437720.5 |
# |    reward_max         | 3437720.5 |
# |    reward_mean        | 3383430.8 |
# |    reward_min         | 3335366.8 |
# |    std                | 0.984     |
# |    value_loss         | 1.21e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 3900      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3899      |
# |    policy_loss        | 4.98e+08  |
# |    reward             | 4321199.0 |
# |    reward_max         | 4333093.5 |
# |    reward_mean        | 4317668.0 |
# |    reward_min         | 4299193.5 |
# |    std                | 0.984     |
# |    value_loss         | 1.96e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 4000      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3999      |
# |    policy_loss        | 6.96e+08  |
# |    reward             | 6076244.0 |
# |    reward_max         | 6076244.0 |
# |    reward_mean        | 6003170.5 |
# |    reward_min         | 5956736.0 |
# |    std                | 0.983     |
# |    value_loss         | 3.81e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6104868.989396519
# Sharpe:  0.9588852575782968
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 4100      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4099      |
# |    policy_loss        | 1.44e+08  |
# |    reward             | 1385347.0 |
# |    reward_max         | 1385347.0 |
# |    reward_mean        | 1379525.4 |
# |    reward_min         | 1373163.1 |
# |    std                | 0.983     |
# |    value_loss         | 1.96e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 4200      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4199      |
# |    policy_loss        | 1.8e+08   |
# |    reward             | 1780217.4 |
# |    reward_max         | 1780217.4 |
# |    reward_mean        | 1755585.0 |
# |    reward_min         | 1730825.6 |
# |    std                | 0.983     |
# |    value_loss         | 3.3e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 4300      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 3.35e+08  |
# |    reward             | 2761669.2 |
# |    reward_max         | 2761669.2 |
# |    reward_mean        | 2721825.8 |
# |    reward_min         | 2704737.0 |
# |    std                | 0.983     |
# |    value_loss         | 8.07e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 4400      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4399      |
# |    policy_loss        | 4.02e+08  |
# |    reward             | 3339563.2 |
# |    reward_max         | 3385853.5 |
# |    reward_mean        | 3353755.5 |
# |    reward_min         | 3312793.8 |
# |    std                | 0.982     |
# |    value_loss         | 1.24e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 4500      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4499      |
# |    policy_loss        | 5.86e+08  |
# |    reward             | 4842124.5 |
# |    reward_max         | 4874994.5 |
# |    reward_mean        | 4857670.0 |
# |    reward_min         | 4841896.5 |
# |    std                | 0.982     |
# |    value_loss         | 2.47e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 4600      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4599      |
# |    policy_loss        | 7.05e+08  |
# |    reward             | 6336056.0 |
# |    reward_max         | 6416337.0 |
# |    reward_mean        | 6363166.0 |
# |    reward_min         | 6301649.0 |
# |    std                | 0.982     |
# |    value_loss         | 4.33e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6287432.86223122
# Sharpe:  0.9681493929567317
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 4700      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.56e+08  |
# |    reward             | 1447357.4 |
# |    reward_max         | 1447357.4 |
# |    reward_mean        | 1424920.0 |
# |    reward_min         | 1399963.8 |
# |    std                | 0.981     |
# |    value_loss         | 2.07e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 4800      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4799      |
# |    policy_loss        | 2.16e+08  |
# |    reward             | 1929083.6 |
# |    reward_max         | 1938530.8 |
# |    reward_mean        | 1934087.1 |
# |    reward_min         | 1929083.6 |
# |    std                | 0.981     |
# |    value_loss         | 3.95e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 4900      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 3.06e+08  |
# |    reward             | 2760900.8 |
# |    reward_max         | 2760900.8 |
# |    reward_mean        | 2741110.5 |
# |    reward_min         | 2718874.5 |
# |    std                | 0.981     |
# |    value_loss         | 7.98e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 5000      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4999      |
# |    policy_loss        | 3.64e+08  |
# |    reward             | 3263297.2 |
# |    reward_max         | 3290134.5 |
# |    reward_mean        | 3272169.5 |
# |    reward_min         | 3258003.5 |
# |    std                | 0.98      |
# |    value_loss         | 1.16e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 5100      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5099      |
# |    policy_loss        | 5.04e+08  |
# |    reward             | 4754180.0 |
# |    reward_max         | 4754180.0 |
# |    reward_mean        | 4715558.5 |
# |    reward_min         | 4659317.5 |
# |    std                | 0.979     |
# |    value_loss         | 2.29e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 5200      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5199      |
# |    policy_loss        | 5.88e+08  |
# |    reward             | 5397295.0 |
# |    reward_max         | 5397295.0 |
# |    reward_mean        | 5278564.5 |
# |    reward_min         | 5216042.5 |
# |    std                | 0.978     |
# |    value_loss         | 3.04e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5770901.388058883
# Sharpe:  0.933343306567373
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 5300      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 1.75e+08  |
# |    reward             | 1592690.1 |
# |    reward_max         | 1592690.1 |
# |    reward_mean        | 1580922.1 |
# |    reward_min         | 1572752.0 |
# |    std                | 0.977     |
# |    value_loss         | 2.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 5400      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5399      |
# |    policy_loss        | 2.32e+08  |
# |    reward             | 2001469.1 |
# |    reward_max         | 2032487.4 |
# |    reward_mean        | 2007567.4 |
# |    reward_min         | 1998990.0 |
# |    std                | 0.978     |
# |    value_loss         | 4.5e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 5500      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5499      |
# |    policy_loss        | 3.37e+08  |
# |    reward             | 2984287.0 |
# |    reward_max         | 2984287.0 |
# |    reward_mean        | 2935226.5 |
# |    reward_min         | 2890656.0 |
# |    std                | 0.977     |
# |    value_loss         | 8.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 5600      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5599      |
# |    policy_loss        | 4.01e+08  |
# |    reward             | 3580237.2 |
# |    reward_max         | 3580237.2 |
# |    reward_mean        | 3573507.8 |
# |    reward_min         | 3564272.5 |
# |    std                | 0.977     |
# |    value_loss         | 1.37e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 5700      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5699      |
# |    policy_loss        | 5.97e+08  |
# |    reward             | 5251945.0 |
# |    reward_max         | 5517276.0 |
# |    reward_mean        | 5323363.5 |
# |    reward_min         | 5223340.0 |
# |    std                | 0.977     |
# |    value_loss         | 3.29e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6205958.1100268485
# Sharpe:  0.9654880435957098
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 5800      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5799      |
# |    policy_loss        | 9.81e+07  |
# |    reward             | 946404.6  |
# |    reward_max         | 953044.94 |
# |    reward_mean        | 940343.94 |
# |    reward_min         | 918742.1  |
# |    std                | 0.976     |
# |    value_loss         | 9.07e+12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 5900      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -37.7     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5899      |
# |    policy_loss        | 1.8e+08   |
# |    reward             | 1587865.2 |
# |    reward_max         | 1590080.8 |
# |    reward_mean        | 1584846.1 |
# |    reward_min         | 1580061.1 |
# |    std                | 0.976     |
# |    value_loss         | 2.64e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 6000      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -37.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5999      |
# |    policy_loss        | 2.37e+08  |
# |    reward             | 2155879.2 |
# |    reward_max         | 2173870.5 |
# |    reward_mean        | 2162216.0 |
# |    reward_min         | 2155879.2 |
# |    std                | 0.975     |
# |    value_loss         | 4.96e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 6100      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -37.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6099      |
# |    policy_loss        | 3.22e+08  |
# |    reward             | 3023783.5 |
# |    reward_max         | 3051496.8 |
# |    reward_mean        | 3020410.8 |
# |    reward_min         | 3003079.5 |
# |    std                | 0.974     |
# |    value_loss         | 1e+14     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 6200      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -37.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6199      |
# |    policy_loss        | 4.16e+08  |
# |    reward             | 3868161.8 |
# |    reward_max         | 3916458.0 |
# |    reward_mean        | 3882689.0 |
# |    reward_min         | 3868161.8 |
# |    std                | 0.974     |
# |    value_loss         | 1.64e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 6300      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -37.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 6.35e+08  |
# |    reward             | 5446549.0 |
# |    reward_max         | 5446549.0 |
# |    reward_mean        | 5423420.5 |
# |    reward_min         | 5403886.0 |
# |    std                | 0.973     |
# |    value_loss         | 3.05e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5942697.285942411
# Sharpe:  0.9336212069505515
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 6400      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -37.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.24e+08  |
# |    reward             | 1240842.8 |
# |    reward_max         | 1240842.8 |
# |    reward_mean        | 1222659.6 |
# |    reward_min         | 1215912.6 |
# |    std                | 0.972     |
# |    value_loss         | 1.51e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# ...
# |    reward_mean        | 3441663.5 |
# |    reward_min         | 3415045.2 |
# |    std                | 0.966     |
# |    value_loss         | 1.2e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 8000      |
# |    time_elapsed       | 143       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -37.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7999      |
# |    policy_loss        | 5.52e+08  |
# |    reward             | 4955187.5 |
# |    reward_max         | 4977335.0 |
# |    reward_mean        | 4943813.5 |
# |    reward_min         | 4893297.5 |
# |    std                | 0.966     |
# |    value_loss         | 2.62e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 8100      |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -37.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8099      |
# |    policy_loss        | 6.8e+08   |
# |    reward             | 6069779.5 |
# |    reward_max         | 6199191.0 |
# |    reward_mean        | 6071001.0 |
# |    reward_min         | 5952354.0 |
# |    std                | 0.965     |
# |    value_loss         | 4.1e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6136891.448562724
# Sharpe:  0.960278049709252
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 8200      |
# |    time_elapsed       | 147       |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8199      |
# |    policy_loss        | 1.67e+08  |
# |    reward             | 1611662.8 |
# |    reward_max         | 1611662.8 |
# |    reward_mean        | 1607369.4 |
# |    reward_min         | 1601039.8 |
# |    std                | 0.965     |
# |    value_loss         | 2.74e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 8300      |
# |    time_elapsed       | 149       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8299      |
# |    policy_loss        | 2.38e+08  |
# |    reward             | 2087180.4 |
# |    reward_max         | 2104355.8 |
# |    reward_mean        | 2083945.6 |
# |    reward_min         | 2066847.9 |
# |    std                | 0.964     |
# |    value_loss         | 4.6e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 8400      |
# |    time_elapsed       | 151       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8399      |
# |    policy_loss        | 3.35e+08  |
# |    reward             | 3044329.2 |
# |    reward_max         | 3148273.0 |
# |    reward_mean        | 3094803.8 |
# |    reward_min         | 3044329.2 |
# |    std                | 0.964     |
# |    value_loss         | 1.08e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 8500      |
# |    time_elapsed       | 152       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8499      |
# |    policy_loss        | 3.9e+08   |
# |    reward             | 3774253.0 |
# |    reward_max         | 3774253.0 |
# |    reward_mean        | 3729582.0 |
# |    reward_min         | 3694173.8 |
# |    std                | 0.963     |
# |    value_loss         | 1.46e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 8600      |
# |    time_elapsed       | 154       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8599      |
# |    policy_loss        | 5.89e+08  |
# |    reward             | 5350808.5 |
# |    reward_max         | 5520706.5 |
# |    reward_mean        | 5438936.5 |
# |    reward_min         | 5350808.5 |
# |    std                | 0.963     |
# |    value_loss         | 2.93e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6035574.184845943
# Sharpe:  0.9472056256708833
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 278        |
# |    iterations         | 8700       |
# |    time_elapsed       | 156        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -37.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 8699       |
# |    policy_loss        | 1.18e+08   |
# |    reward             | 1036172.75 |
# |    reward_max         | 1036172.75 |
# |    reward_mean        | 1024206.06 |
# |    reward_min         | 1003594.8  |
# |    std                | 0.963      |
# |    value_loss         | 1.03e+13   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 8800      |
# |    time_elapsed       | 157       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8799      |
# |    policy_loss        | 1.81e+08  |
# |    reward             | 1603083.8 |
# |    reward_max         | 1603083.8 |
# |    reward_mean        | 1597154.9 |
# |    reward_min         | 1593393.2 |
# |    std                | 0.963     |
# |    value_loss         | 2.78e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 8900      |
# |    time_elapsed       | 159       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8899      |
# |    policy_loss        | 2.52e+08  |
# |    reward             | 2211307.0 |
# |    reward_max         | 2223664.2 |
# |    reward_mean        | 2213991.2 |
# |    reward_min         | 2207578.0 |
# |    std                | 0.963     |
# |    value_loss         | 5.16e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 9000      |
# |    time_elapsed       | 161       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8999      |
# |    policy_loss        | 3.05e+08  |
# |    reward             | 2968601.2 |
# |    reward_max         | 2983525.8 |
# |    reward_mean        | 2975672.5 |
# |    reward_min         | 2968601.2 |
# |    std                | 0.963     |
# |    value_loss         | 9.21e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9100      |
# |    time_elapsed       | 163       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9099      |
# |    policy_loss        | 4.12e+08  |
# |    reward             | 3745353.5 |
# |    reward_max         | 3745353.5 |
# |    reward_mean        | 3731208.5 |
# |    reward_min         | 3721112.0 |
# |    std                | 0.963     |
# |    value_loss         | 1.49e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9200      |
# |    time_elapsed       | 165       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 5.42e+08  |
# |    reward             | 5045572.0 |
# |    reward_max         | 5124695.0 |
# |    reward_mean        | 5052049.0 |
# |    reward_min         | 5014393.5 |
# |    std                | 0.962     |
# |    value_loss         | 2.8e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5473960.791525543
# Sharpe:  0.9048115057526389
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9300      |
# |    time_elapsed       | 167       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9299      |
# |    policy_loss        | 1.35e+08  |
# |    reward             | 1261774.1 |
# |    reward_max         | 1280508.4 |
# |    reward_mean        | 1259077.1 |
# |    reward_min         | 1247193.0 |
# |    std                | 0.962     |
# |    value_loss         | 1.72e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9400      |
# |    time_elapsed       | 168       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9399      |
# |    policy_loss        | 1.8e+08   |
# |    reward             | 1754668.6 |
# |    reward_max         | 1755654.8 |
# |    reward_mean        | 1721122.1 |
# |    reward_min         | 1683138.4 |
# |    std                | 0.961     |
# |    value_loss         | 2.95e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9500      |
# |    time_elapsed       | 170       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9499      |
# |    policy_loss        | 3.11e+08  |
# |    reward             | 2631543.5 |
# |    reward_max         | 2631543.5 |
# |    reward_mean        | 2615639.5 |
# |    reward_min         | 2603541.2 |
# |    std                | 0.961     |
# |    value_loss         | 7.17e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9600      |
# |    time_elapsed       | 172       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9599      |
# |    policy_loss        | 3.6e+08   |
# |    reward             | 3245656.5 |
# |    reward_max         | 3261551.8 |
# |    reward_mean        | 3254677.8 |
# |    reward_min         | 3245656.5 |
# |    std                | 0.96      |
# |    value_loss         | 1.12e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9700      |
# |    time_elapsed       | 174       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9699      |
# |    policy_loss        | 4.84e+08  |
# |    reward             | 4513362.0 |
# |    reward_max         | 4513362.0 |
# |    reward_mean        | 4500419.5 |
# |    reward_min         | 4490848.5 |
# |    std                | 0.96      |
# |    value_loss         | 2.14e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9800      |
# |    time_elapsed       | 175       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9799      |
# |    policy_loss        | 6.9e+08   |
# |    reward             | 5865070.0 |
# |    reward_max         | 5865070.0 |
# |    reward_mean        | 5794491.0 |
# |    reward_min         | 5730558.5 |
# |    std                | 0.96      |
# |    value_loss         | 3.57e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5926396.843489741
# Sharpe:  0.9465274521268624
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 9900      |
# |    time_elapsed       | 177       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9899      |
# |    policy_loss        | 1.58e+08  |
# |    reward             | 1533516.4 |
# |    reward_max         | 1533516.4 |
# |    reward_mean        | 1526198.1 |
# |    reward_min         | 1517160.1 |
# |    std                | 0.959     |
# |    value_loss         | 2.46e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 10000     |
# |    time_elapsed       | 179       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9999      |
# |    policy_loss        | 2.35e+08  |
# |    reward             | 2065478.2 |
# |    reward_max         | 2072420.9 |
# |    reward_mean        | 2061874.5 |
# |    reward_min         | 2053185.8 |
# |    std                | 0.959     |
# |    value_loss         | 4.51e+13  |
# -------------------------------------

# %%
trained_a2c.save('/content/trained_models/trained_a2c.zip')

# %% [markdown]
# ### Model 2: **PPO**

# %%
# agent = DRLAgent(env = env_train)
# PPO_PARAMS = {
#     "n_steps": 2048,
#     "ent_coef": 0.005,
#     "learning_rate": 0.0001,
#     "batch_size": 128,
# }
# model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

# %%
# trained_ppo = agent.train_model(model=model_ppo,
#                              tb_log_name='ppo',
#                              total_timesteps=80000)

# %%
# trained_ppo.save('/content/trained_models/trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
# agent = DRLAgent(env = env_train)
# DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


# model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)

# %%
# trained_ddpg = agent.train_model(model=model_ddpg,
#                              tb_log_name='ddpg',
#                              total_timesteps=50000)

# %%
# trained_ddpg.save('/content/trained_models/trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
# agent = DRLAgent(env = env_train)
# SAC_PARAMS = {
#     "batch_size": 128,
#     "buffer_size": 100000,
#     "learning_rate": 0.0003,
#     "learning_starts": 100,
#     "ent_coef": "auto_0.1",
# }

# model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

# %%
# trained_sac = agent.train_model(model=model_sac,
#                              tb_log_name='sac',
#                              total_timesteps=50000)

# %%
# trained_sac.save('/content/trained_models/trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
# agent = DRLAgent(env = env_train)
# TD3_PARAMS = {"batch_size": 100,
#               "buffer_size": 1000000,
#               "learning_rate": 0.001}

# model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

# %%
# trained_td3 = agent.train_model(model=model_td3,
#                              tb_log_name='td3',
#                              total_timesteps=30000)

# %%
# trained_td3.save('/content/trained_models/trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
trade = data_split(df,'2020-07-01', '2021-10-31')
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
trade.shape
# Out:
# (9099, 18)

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)
# Out:
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1414748.0995353241
# Sharpe:  2.0042744273205786
# =================================
# hit end!
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df_daily_return.head()
# Out:
#          date  daily_return
# 0  2020-07-01      0.000000
# 1  2020-07-02      0.003494
# 2  2020-07-06      0.014956
# 3  2020-07-07     -0.013050
# 4  2020-07-08      0.005539
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df_daily_return.to_csv('df_daily_return.csv')

# %%
df_actions.head()
# Out:
#                 AAPL      AMGN       AXP        BA       CAT       CRM  \
# date
# 2020-07-01  0.037037  0.037037  0.037037  0.037037  0.037037  0.037037
# 2020-07-02  0.031123  0.031123  0.031123  0.031123  0.031123  0.031123
# 2020-07-06  0.031578  0.031578  0.031578  0.031578  0.031578  0.031578
# 2020-07-07  0.031132  0.031350  0.031132  0.031132  0.031132  0.031132
# 2020-07-08  0.031100  0.031100  0.031100  0.031100  0.031100  0.031100
#
#                 CSCO       CVX       DIS        GS  ...       MCD       MMM  \
# date                                                ...
# 2020-07-01  0.037037  0.037037  0.037037  0.037037  ...  0.037037  0.037037
# 2020-07-02  0.075037  0.031123  0.031123  0.031123  ...  0.031123  0.031123
# 2020-07-06  0.068993  0.032009  0.031578  0.031578  ...  0.031578  0.031578
# 2020-07-07  0.072027  0.032595  0.031132  0.031132  ...  0.031132  0.032047
# 2020-07-08  0.075358  0.031100  0.031100  0.031100  ...  0.031100  0.031100
#
#                  MRK      MSFT       NKE        PG       TRV       UNH  \
# date
# 2020-07-01  0.037037  0.037037  0.037037  0.037037  0.037037  0.037037
# 2020-07-02  0.031123  0.033622  0.031123  0.031123  0.031123  0.032901
# 2020-07-06  0.031578  0.034420  0.031578  0.031578  0.031578  0.033217
# 2020-07-07  0.031132  0.035814  0.031132  0.031132  0.031132  0.031223
# 2020-07-08  0.031100  0.033593  0.031100  0.031100  0.031100  0.032873
#
#                   VZ       WMT
# date
# 2020-07-01  0.037037  0.037037
# 2020-07-02  0.047040  0.031123
# 2020-07-06  0.046446  0.031578
# 2020-07-07  0.047194  0.031132
# 2020-07-08  0.047051  0.031100
#
# [5 rows x 27 columns]
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
df_actions.to_csv('df_actions.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
from pyfolio import timeseries
DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats
perf_stats_all = perf_func( returns=DRL_strat,
                              factor_returns=DRL_strat,
                                positions=None, transactions=None, turnover_denom="AGB")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all
# Out:
# ==============DRL Strategy Stats===========
# Annual return          0.296206
# Cumulative returns     0.414748
# Annual volatility      0.133977
# Sharpe ratio           2.004274
# Calmar ratio           3.464214
# Stability              0.926908
# Max drawdown          -0.085505
# Omega ratio            1.397209
# Sortino ratio          3.030197
# Skew                  -0.230280
# Kurtosis               1.311977
# Tail ratio             1.038573
# Daily value at risk   -0.015814
# Alpha                  0.000000
# Beta                   1.000000
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI",
        start = df_daily_return.loc[0,'date'],
        end = df_daily_return.loc[len(df_daily_return)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.279047
# Cumulative returns     0.388402
# Annual volatility      0.139129
# Sharpe ratio           1.844560
# Calmar ratio           3.124551
# Stability              0.918675
# Max drawdown          -0.089308
# Omega ratio            1.358960
# Sortino ratio          2.734872
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016510
# dtype: float64
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# %matplotlib inline

baseline_df = get_baseline(
        ticker='^DJI', start=df_daily_return.loc[0,'date'], end='2021-11-01'
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (337, 8)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# /usr/local/lib/python3.12/dist-packages/pyfolio/plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '29.621%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>29.621%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>41.475%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.398%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.46</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.55%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.40</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.03</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.23</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.31</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.581%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.95</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.55</td>
#       <td>2020-09-02</td>
#       <td>2020-10-28</td>
#       <td>2020-11-09</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.60</td>
#       <td>2021-08-16</td>
#       <td>2021-09-30</td>
#       <td>2021-10-28</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.82</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-07-02</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.71</td>
#       <td>2021-01-21</td>
#       <td>2021-01-29</td>
#       <td>2021-02-05</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.20</td>
#       <td>2021-05-10</td>
#       <td>2021-05-12</td>
#       <td>2021-06-04</td>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/pyfolio/plotting.py:1407: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Daily", "Weekly", "Monthly"])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Covid</th>
#       <td>0.11%</td>
#       <td>-3.22%</td>
#       <td>3.48%</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
# %pip install PyPortfolioOpt
# Out:
# Requirement already satisfied: PyPortfolioOpt in /usr/local/lib/python3.12/dist-packages (1.5.6)
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (1.6.7)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (2.0.14)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (2.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (2.2.2)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (5.24.1)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.12/dist-packages (from PyPortfolioOpt) (1.16.3)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (1.0.5)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.12/dist-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (3.2.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (24.2)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (75.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (1.5.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->PyPortfolioOpt) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (2.23)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.0.3)

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
df.head()
# Out:
#          date      close       high        low       open     volume   tic  \
# 0  2008-12-31   2.559735   2.631414   2.559436   2.578330  607541200  AAPL
# 1  2008-12-31  39.612652  39.935041  39.139359  39.173655    6287200  AMGN
# 2  2008-12-31  14.254668  14.408358  13.762863  13.808970    9625600   AXP
# 3  2008-12-31  32.005882  32.290913  31.128291  31.195798    5443100    BA
# 4  2008-12-31  28.707743  28.984088  28.084362  28.084362    6277400   CAT
#
#    day      macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0    2 -0.081830   3.064709   2.431330  42.254781  -80.847156  16.129827
# 1    2  0.148413  40.433988  38.678810  51.060626   51.895905  10.431911
# 2    2 -0.914660  18.229859  12.377338  42.554843  -74.811831  25.744903
# 3    2 -0.279802  32.174385  28.867831  47.440231  157.921643   5.391946
# 4    2  0.635663  29.424678  24.681105  51.205305   98.904532  26.480643
#
#    close_30_sma  close_60_sma  \
# 0      2.723837      2.834898
# 1     38.872752     38.442671
# 2     15.391970     17.222407
# 3     30.327213     32.389915
# 4     25.877462     25.619594
#
#                                             cov_list  \
# 0  [[0.001348969167393465, 0.0004284132113294488,...
# 1  [[0.001348969167393465, 0.0004284132113294488,...
# 2  [[0.001348969167393465, 0.0004284132113294488,...
# 3  [[0.001348969167393465, 0.0004284132113294488,...
# 4  [[0.001348969167393465, 0.0004284132113294488,...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
initial_capital = 1000000
portfolio.loc[0,unique_trade_date[0]] = initial_capital

for i in range(len( unique_trade_date)-1):
    df_temp = df[df.date==unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date==unique_trade_date[i+1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma,weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()

    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                                      / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value
    portfolio.iloc[0, i+1] = np.dot(current_shares, next_price)

portfolio=portfolio.T
portfolio.columns = ['account_value']
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
portfolio.head()
# Out:
#              account_value
# 2020-07-01         1000000
# 2020-07-02  1004237.627099
# 2020-07-06  1013513.046547
# 2020-07-07  1012906.339985
# 2020-07-08  1012221.140318
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
a2c_cumpod =(df_daily_return.daily_return+1).cumprod()-1

# %%
min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1
# Out:
# /tmp/ipython-input-3389022641.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1

# %%
dji_cumpod =(baseline_returns+1).cumprod()-1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (24.2)

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
trace0_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod, mode = 'lines', name = 'A2C (Portfolio Allocation)')

trace1_portfolio = go.Scatter(x = time_ind, y = dji_cumpod, mode = 'lines', name = 'DJIA')
trace2_portfolio = go.Scatter(x = time_ind, y = min_var_cumpod, mode = 'lines', name = 'Min-Variance')
#trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
#trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
#trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)



fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2

    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
#    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
xaxis={'type': 'date',
       'tick0': time_ind[0],
        'tickmode': 'linear',
       'dtick': 86400000.0 *80}

)
fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61a91c73-dc11-4a1e-9306-e170167d3e2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61a91c73-dc11-4a1e-9306-e170167d3e2d")) {                    Plotly.newPlot(                        "61a91c73-dc11-4a1e-9306-e170167d3e2d",                        [{"mode":"lines","name":"A2C (Portfolio Allocation)","x":["2020-07-01","2020-07-02","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-31","2020-09-01","2020-09-02","2020-09-03","2020-09-04","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-28","2020-09-29","2020-09-30","2020-10-01","2020-10-02","2020-10-05","2020-10-06","2020-10-07","2020-10-08","2020-10-09","2020-10-12","2020-10-13","2020-10-14","2020-10-15","2020-10-16","2020-10-19","2020-10-20","2020-10-21","2020-10-22","2020-10-23","2020-10-26","2020-10-27","2020-10-28","2020-10-29","2020-10-30","2020-11-02","2020-11-03","2020-11-04","2020-11-05","2020-11-06","2020-11-09","2020-11-10","2020-11-11","2020-11-12","2020-11-13","2020-11-16","2020-11-17","2020-11-18","2020-11-19","2020-11-20","2020-11-23","2020-11-24","2020-11-25","2020-11-27","2020-11-30","2020-12-01","2020-12-02","2020-12-03","2020-12-04","2020-12-07","2020-12-08","2020-12-09","2020-12-10","2020-12-11","2020-12-14","2020-12-15","2020-12-16","2020-12-17","2020-12-18","2020-12-21","2020-12-22","2020-12-23","2020-12-24","2020-12-28","2020-12-29","2020-12-30","2020-12-31","2021-01-04","2021-01-05","2021-01-06","2021-01-07","2021-01-08","2021-01-11","2021-01-12","2021-01-13","2021-01-14","2021-01-15","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-02-01","2021-02-02","2021-02-03","2021-02-04","2021-02-05","2021-02-08","2021-02-09","2021-02-10","2021-02-11","2021-02-12","2021-02-16","2021-02-17","2021-02-18","2021-02-19","2021-02-22","2021-02-23","2021-02-24","2021-02-25","2021-02-26","2021-03-01","2021-03-02","2021-03-03","2021-03-04","2021-03-05","2021-03-08","2021-03-09","2021-03-10","2021-03-11","2021-03-12","2021-03-15","2021-03-16","2021-03-17","2021-03-18","2021-03-19","2021-03-22","2021-03-23","2021-03-24","2021-03-25","2021-03-26","2021-03-29","2021-03-30","2021-03-31","2021-04-01","2021-04-05","2021-04-06","2021-04-07","2021-04-08","2021-04-09","2021-04-12","2021-04-13","2021-04-14","2021-04-15","2021-04-16","2021-04-19","2021-04-20","2021-04-21","2021-04-22","2021-04-23","2021-04-26","2021-04-27","2021-04-28","2021-04-29","2021-04-30","2021-05-03","2021-05-04","2021-05-05","2021-05-06","2021-05-07","2021-05-10","2021-05-11","2021-05-12","2021-05-13","2021-05-14","2021-05-17","2021-05-18","2021-05-19","2021-05-20","2021-05-21","2021-05-24","2021-05-25","2021-05-26","2021-05-27","2021-05-28","2021-06-01","2021-06-02","2021-06-03","2021-06-04","2021-06-07","2021-06-08","2021-06-09","2021-06-10","2021-06-11","2021-06-14","2021-06-15","2021-06-16","2021-06-17","2021-06-18","2021-06-21","2021-06-22","2021-06-23","2021-06-24","2021-06-25","2021-06-28","2021-06-29","2021-06-30","2021-07-01","2021-07-02","2021-07-06","2021-07-07","2021-07-08","2021-07-09","2021-07-12","2021-07-13" ...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
